# %%
import pandas as pd

# %%
df=pd.read_csv("StudentPerformanceFactors.csv")

# %%
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
len(df["Hours_Studied"])
# Out:
# 41

# %%
df.count()
# Out:
# Hours_Studied                 41
# Attendance                    41
# Parental_Involvement          41
# Access_to_Resources           41
# Extracurricular_Activities    41
# Sleep_Hours                   41
# Previous_Scores               41
# Motivation_Level              41
# Internet_Access               41
# Tutoring_Sessions             41
# Family_Income                 41
# Teacher_Quality               41
# School_Type                   41
# Peer_Influence                41
# Physical_Activity             41
# Learning_Disabilities         41
# Parental_Education_Level      40
# Distance_from_Home            41
# Gender                        41
# Exam_Score                    41
# dtype: int64

# %%
#selection
df_new=df[['Physical_Activity','Gender','Hours_Studied','Distance_from_Home','Exam_Score']].loc[1:6]
df_new
# Out:
#    Physical_Activity  Gender  Hours_Studied Distance_from_Home  Exam_Score
# 1                  4  Female             19           Moderate          61
# 2                  4    Male             24               Near          74
# 3                  4    Male             29           Moderate          71

# %%
#sorting
df_new.columns=['Hours_activity','Gender','Study_Hour','Parent_involvement','Exam_Score']
Topper=df_new.sort_values('Exam_Score',ascending=False).head(10)
Topper
# Out:
#       Hours_activity  Gender  Study_Hour Parent_involvement  Exam_Score
# 113                2  Female          35               Near          79
# 209                1  Female          43               Near          78
# 1615               3    Male          39           Moderate          77
# 2035               3    Male          37               Near          76
# 2                  4    Male          24               Near          74
# 118                5  Female          27               Near          73
# 478                3    Male          38               Near          73
# 3                  4    Male          29           Moderate          71
# 2895               2  Female          44           Moderate          71
# 12                 4    Male          21               Near          70

# %%
Topper["Exam_Score"].head(1)
# Out:
# 113    79
# Name: Exam_Score, dtype: int64

# %%
#filtering
student_record=df[(df["School_Type"]=='Public')& (df["Peer_Influence"]=='Positive')& (df["Learning_Disabilities"]=='No')&
                  (df["Hours_Studied"]>20)& (df["Attendance"]>80)& (df["Previous_Scores"]>60)]
student_record
# Out:
#      Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0               23          84                  Low                High
# 12              21          83               Medium              Medium
# 118             27          97                  Low                High
# 209             43          86                 High              Medium
#
#     Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# 0                           No            7               73              Low
# 12                         Yes            8               97              Low
# 118                        Yes            8               81           Medium
# 209                        Yes            7               97           Medium
#
#     Internet_Access  Tutoring_Sessions Family_Income Teacher_Quality  \
# 0               Yes                  0           Low          Medium
# 12              Yes                  2        Medium          Medium
# ...

# %%
female_record=student_record[['Hours_Studied','Gender','Parental_Involvement','Sleep_Hours']]
female_record
# Out:
#      Hours_Studied  Gender Parental_Involvement  Sleep_Hours
# 0               23    Male                  Low            7
# 12              21    Male               Medium            8
# 118             27  Female                  Low            8
# 209             43  Female                 High            7

# %%
female_record.max()
# Out:
# Hours_Studied               43
# Gender                    Male
# Parental_Involvement    Medium
# Sleep_Hours                  8
# dtype: object

# %%
#mathematical computation
female_record["Hours_Studied"].sum()
# Out:
# np.int64(114)

# %%
#slicing
df_list=df_new.values.tolist()
df_list
# Out:
# [[3, 'Male', 23, 'Near', 67],
#  [4, 'Female', 19, 'Moderate', 61],
#  [4, 'Male', 24, 'Near', 74],
#  [4, 'Male', 29, 'Moderate', 71],
#  [2, 'Male', 25, 'Far', 66],
#  [1, 'Male', 17, 'Near', 69],
#  [4, 'Male', 21, 'Near', 70],
#  [3, 'Male', 9, 'Near', 66],
#  [4, 'Male', 10, 'Near', 65],
#  [3, 'Male', 14, 'Near', 60],
#  [3, 'Female', 22, 'Near', 65],
#  [2, 'Female', 15, 'Moderate', 67],
#  [4, 'Male', 12, 'Near', 66],
#  [2, 'Female', 20, 'Moderate', 66],
#  [3, 'Male', 11, 'Moderate', 66],
#  [2, 'Female', 13, 'Moderate', 65],
#  [3, 'Female', 16, 'Moderate', 66],
#  [2, 'Male', 18, 'Near', 64],
#  [3, 'Male', 31, 'Near', 69],
#  [5, 'Female', 8, 'Near', 67],
#  [3, 'Female', 26, 'Moderate', 64],
#  [2, 'Male', 28, 'Near', 68],
#  [4, 'Male', 4, 'Moderate', 69],
#  [2, 'Female', 35, 'Near', 79],
#  [5, 'Female', 27, 'Near', 73],
#  [4, 'Male', 33, 'Near', 69],
#  [2, 'Male', 36, 'Far', 69],
#  [1, 'Female', 43, 'Near', 78],
#  [3, 'Male', 34, 'Near', 69],
# ...

# %%
df_list[0:10] #1st ten
# Out:
# [[3, 'Male', 23, 'Near', 67],
#  [4, 'Female', 19, 'Moderate', 61],
#  [4, 'Male', 24, 'Near', 74],
#  [4, 'Male', 29, 'Moderate', 71],
#  [2, 'Male', 25, 'Far', 66],
#  [1, 'Male', 17, 'Near', 69],
#  [4, 'Male', 21, 'Near', 70],
#  [3, 'Male', 9, 'Near', 66],
#  [4, 'Male', 10, 'Near', 65],
#  [3, 'Male', 14, 'Near', 60]]

# %%
df_list[-1] #last data
# Out:
# [2, 'Female', 44, 'Moderate', 71]

# %%
df.loc[[0,2],["Hours_Studied","Peer_Influence"]]
# Out:
#    Hours_Studied Peer_Influence
# 0             23       Positive
# 2             24        Neutral

# %%
df.iloc[[0,3],[3,4]]
# Out:
#   Access_to_Resources Extracurricular_Activities
# 0                High                         No
# 3              Medium                        Yes

# %%
#add date
df=df.copy()
df.loc[ :,'Date']=pd.date_range('2024-06-02',periods=len(df))
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 7                25          78                  Low                High
# 8                17          94               Medium                High
# 12               21          83               Medium              Medium
# 13                9          82               Medium              Medium
# 14               10          78               Medium                High
# 16               14          60               Medium                 Low
# 17               22          70                  Low              Medium
# 18               15          80               Medium              Medium
# ...

# %%
df_group = df.groupby([df['Date'].dt.day, 'Attendance','Sleep_Hours'])['Hours_Studied'].sum().reset_index()
print(df_group)
# Out:
#     Date  Attendance  Sleep_Hours  Hours_Studied
# 0      1          69            6              1
# 1      2          81            5             30
# 2      2          84            7             23
# 3      3          64            8             19
# 4      3          82            8              7
# 5      4          68            8             32
# 6      4          98            7             24
# 7      5          89            8             29
# 8      5          93            7              6
# 9      6          78            6             25
# 10     6          86            7             38
# 11     7          84            8              5
# 12     7          94            6             17
# 13     8          83            8             21
# 14     8          85            8              3
# 15     9          82            8              9
# 16     9          84            8              2
# 17    10          78            8             10
# ...

# %%
df_group = df.groupby([df['Date'].dt.day])['Hours_Studied'].sum().reset_index()
df_group
# Out:
#     Date  Hours_Studied
# 0      1              1
# 1      2             53
# 2      3             26
# 3      4             56
# 4      5             35
# 5      6             63
# 6      7             22
# 7      8             24
# 8      9             11
# 9     10             49
# 10    11             51
# 11    12             66
# 12    13             15
# 13    14             12
# 14    15             20
# 15    16             11
# 16    17             13
# 17    18             16
# 18    19             18
# 19    20             31
# 20    21              8
# 21    22             26
# 22    23             28
# 23    24              4
# 24    25             35
# 25    26             27
# 26    27             33
# 27    28             36
# 28    29             43
# 29    30             34
